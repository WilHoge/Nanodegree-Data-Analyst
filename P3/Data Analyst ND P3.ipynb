# %%
import xml.etree.cElementTree as ET
import pprint
import sys
import re
from collections import defaultdict
import codecs
import json

OSM = "/Users/wilfriedhoge/Downloads/MUC.osm"

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
expected = [u'Stra\xdfe', "Allee", "Platz", "Weg", "Ring", u"Chause\xe8", u'Br\xfccke', "Berg", "Park",
           "Feld", "Graben", "Holz", "Siedlung", "Steig", "Weiher", "Bach", "Anger"]
expectedEnds = ["weg", "-Weg","-Platz", "platz", u'stra\xdfe', u'-Stra\xdfe', "promenade", "-Bogen", "-Ring",
               "gasse", "-Gasse", "allee", "-Allee", "bogen", "graben", "see", "feld", "leiten", "berg", "ring",
               "rain", "burg", "leite", "bach", "tal", "wiese", "garten", "anger", "acker", "thal", "hof", "wald",
               "-Anger", "ried", "dorf", "-Damm", "damm", "-Passage", u"m\xfchle", "gassl", "steig", u'-Br\xfccke',
               "park", "pfad", "wies", "viertel", "ufer", "hof", "haus", "weide", "kanal", "-Hof", "mark", "winkel",
               "zentrum", "hausen", "bauer", "blick", "hofen", "wall", "brunnen", "breite", "hain", "fleck",
               "passage", "schlag", "tor", "holz", "hort", "-Siedlung", "weiden", "stein", "kam", "grube", "grund"]


expectedCity = [u'M\xfcnchen']
mappingCity = { "MU": u'M\xfcnchen',
               u'M\xfcchen': u'M\xfcnchen',
               "Munchen": u'M\xfcnchen',
               "Munich": u'M\xfcnchen',
               u'M\xfcnschen':u'M\xfcnchen',
               u'M\xdc': u'M\xfcnchen',
               u'M\xfcchen': u'M\xfcnchen',
               u'M\xfcchnen': u'M\xfcnchen',
               u'M\xfcnchen\u200e': u'M\xfcnchen',
               u'M\xfcnschen': u'M\xfcnchen',
               u'Haar bei M\xfcnchen': 'Haar',
               u'Gr\xe4felfing bei M\xfcnchen':u'Gr\xe4felfing'
            }

# %%
def count_tags(filename):
    tags = {}
    i = 1
    for _, elem in ET.iterparse(filename):
        if elem.tag not in tags:
            tags[elem.tag] = 1
        else:
            tags[elem.tag] += 1
        if i > 300000:
            sys.stdout.write('*')
            i = 1
        else:
            i += 1

    sys.stdout.write('\n')    
    return tags 
        
if True:
    tags = count_tags(OSM)
    print tags
# Out:
# ******************
# {'node': 1486269, 'member': 137545, 'remark': 1, 'nd': 1959807, 'tag': 1634060, 'note': 1, 'meta': 1, 'relation': 5421, 'way': 291987, 'osm': 1}

# %%
def key_type(element, keys, problematics, others):
    if element.tag == "tag":
        for i in element.iter():
            if (lower.search(i.attrib["k"])):
                keys["lower"] += 1
            elif (lower_colon.search(i.attrib["k"])):
                keys["lower_colon"] += 1
            elif (problemchars.search(i.attrib["k"])):
                problematics.add(i.attrib["k"])
                keys["problemchars"] += 1
            else:
                others.add(i.attrib["k"])
                keys["other"] += 1
        
    return keys

def process_map(filename):
    i = 1
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    problematics = set()
    others = set()
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys, problematics, others)
        if i > 300000:
            sys.stdout.write('*')
            i = 1
        else:
            i += 1
    
    sys.stdout.write('\n') 
    return keys, problematics, others

if True:
    keys, problematics, others = process_map(OSM)
    print "Key list:"
    pprint.pprint(keys)
    print "\nProblematic keys:"
    pprint.pprint(problematics)
    print "\nOther keys:"
    pprint.pprint(others)
# Out:
# ******************
# Key list:
# {'lower': 802489, 'lower_colon': 821809, 'other': 9424, 'problemchars': 338}
#
# Problematic keys:
# set(['addr.source:housenumber',
#      'contact.source:website',
#      'footway:left.sloped_curb.end',
#      'footway:left.sloped_curb.start',
#      'footway:left.smoothness',
#      'footway:left.surface',
#      'footway:left.wheelchair',
#      'footway:left.wheelchair.end',
#      'footway:left.wheelchair.start',
#      'footway:left.width',
#      'footway:right.sloped_curb.end',
#      'footway:right.sloped_curb.start',
#      'footway:right.smoothness',
#      'footway:right.surface',
#      'footway:right.wheelchair',
#      'footway:right.wheelchair.end',
#      'footway:right.wheelchair.start',
#      'footway:right.width',
#      'step.condition',
#      'step.height',
#      'surface.material'])
#
# Other keys:
# set(['3dr:direction',
#      '3dr:entrance',
#      '3dr:h1',
#      '3dr:type',
#      'BLfD:criteria',
#      'Bayernets',
#      'FIXME',
#      'Gewerbeeinheiten',
#      'ISO3166-2',
#      'Ladezone',
#      'Palios',
#      'Sanierungsjahr',
#      'TMC:cid_58:tabcd_1:Class',
#      'TMC:cid_58:tabcd_1:Direction',
#      'TMC:cid_58:tabcd_1:LCLversion',
#      'TMC:cid_58:tabcd_1:LocationCode',
#      'TMC:cid_58:tabcd_1:NextLocationCode',
#      'TMC:cid_58:tabcd_1:PrevLocationCode',
#      'TMC:cid_58:tabcd_1:TypeName',
#      'TMC:cid_58:tabcd_1:TypeName:loc',
#      'Xuits',
#      'Zugangsrechte',
#      'access:backward:conditional',
#      'access:fuel:lpg',
#      'access:hgv:note',
#      'access:lanes:forward',
#      'addr:housenumber:source',
#      'aed:note:de',
#      'area:highway:crossing',
#      'associatedStreet',
#      'blind:description:de',
#      'blind:description:en',
#      'brewery:Becks',
#      'brewery:Dunkels',
#      'brewery:Helles',
#      'brewery:Pils',
#      'brewery:Weizen',
#      'brewery:Weizenbier',
#      'building:facade:color',
#      'building:level:1:colour',
#      'building:levels:top',
#      'building:levels:underground',
#      'building:roof:edge',
#      'building:roof:material',
#      'building:roof:orientation',
#      'building:roof:ridge',
#      'building:roof:shape',
#      u'b\xb4high',
#      'change:lanes:backward',
#      'change:lanes:forward',
#      'cinema:3D',
#      'class:bicycle:mtb',
#      'climbing:grade:UIAA:max',
#      'climbing:grade:UIAA:min',
#      'climbing:length:max',
#      'climbing:length:min',
#      'contact:phone:tickets',
#      'contact:website_1',
#      'currency:DM',
#      'currency:EUR',
#      'cycleway:both:bicycle',
#      'cycleway:both:segregated',
#      'cycleway:left:oneway',
#      'cycleway:right:bicycle',
#      'cycleway:right:foot',
#      'cycleway:right:oneway',
#      'cycleway:right:segregated',
#      'cycleway:right:surface',
#      'description:2',
#      'destination:colour:lanes',
#      'destination:country:lanes',
#      'destination:ref:backward',
#      'destination:ref:forward',
#      'destination:ref:lanes',
#      'destination:symbol:lanes',
#      'disused:addr:housenumber',
#      'disused:addr:street',
#      'disused:building:part',
#      'disused:name:en',
#      'disused:tickets:public_transport',
#      'drink:afri-cola',
#      'drink:club-mate',
#      'drink:fritz-kola',
#      'drink:leet-mate',
#      'e-road:class',
#      'entrance:SEV',
#      'event:0:category',
#      'event:0:enddate',
#      'event:0:howoften',
#      'event:0:name',
#      'event:0:num_participants',
#      'event:0:organization',
#      'event:0:related_items',
#      'event:0:startdate',
#      'event:0:subcategory',
#      'event:0:url',
#      'event:1:category',
#      'event:1:enddate',
#      'event:1:howoften',
#      'event:1:name',
#      'event:1:organization',
#      'event:1:startdate',
#      'event:1:subcategory',
#      'event:1:url',
#      'event:2:category',
#      'event:2:howoften',
#      'event:2:name',
#      'event:2:startdate',
#      'event:2:subcategory',
#      'event:2:url',
#      'event:3:category',
#      'event:3:howoften',
#      'event:3:name',
#      'event:3:startdate',
#      'event:3:subcategory',
#      'event:3:url',
#      'event:4:category',
#      'event:4:howoften',
#      'event:4:name',
#      'event:4:startdate',
#      'event:4:subcategory',
#      'event:4:url',
#      'footway:left:incline',
#      'footway:left:smoothness',
#      'footway:left:surface',
#      'footway:left:width',
#      'footway:right:incline',
#      'footway:right:smoothness',
#      'footway:right:surface',
#      'footway:right:width',
#      'fuel:1_25',
#      'fuel:1_50',
#      'fuel:GTL_diesel',
#      'fuel:HGV_diesel',
#      'fuel:LH2',
#      'fuel:cetane_60',
#      'fuel:e10',
#      'fuel:e85',
#      'fuel:octane_100',
#      'fuel:octane_91',
#      'fuel:octane_95',
#      'fuel:octane_98',
#      u'gemeinn\xfctzig',
#      'generator:output:electricity',
#      'generator:output:hot_water',
#      'generator:output:steam',
#      'healthcare:speciality:de',
#      'healthcare:speciality:orthopaedics',
#      'highway_1',
#      'inscription2',
#      'is_in:iso_3166_2',
#      'iso3166-2',
#      'landuse_1',
#      'lanes:psv:conditional',
#      'massgis:PUB_ACCESS',
#      'maxspeed:hgv:conditional',
#      'mtb:scale:imba',
#      'mtb:scale:uphill',
#      'name1',
#      'name2',
#      'name3',
#      'name:MVV',
#      'name:prefix:de',
#      'name:suffix:en',
#      'name:suffix:fr',
#      'name_1',
#      'name_2',
#      'name_3',
#      'naptan:Bearing',
#      'note2',
#      'note:1',
#      'note:2',
#      'note:2013',
#      'note:2014',
#      'note:3',
#      'note:4',
#      'note:levels:de',
#      'note:sidewalk:de',
#      'old:addr:housenumber',
#      'old:addr:street',
#      'old_name_1',
#      'on_air:frequency:digital',
#      'on_air:hours:digital',
#      'openGeoDB:auto_update',
#      'openGeoDB:community_identification_number',
#      'openGeoDB:is_in',
#      'openGeoDB:is_in_loc_id',
#      'openGeoDB:layer',
#      'openGeoDB:license_plate_code',
#      'openGeoDB:loc_id',
#      'openGeoDB:location',
#      'openGeoDB:name',
#      'openGeoDB:population',
#      'openGeoDB:postal_codes',
#      'openGeoDB:sort_name',
#      'openGeoDB:telephone_area_code',
#      'openGeoDB:type',
#      'openGeoDB:version',
#      'osmarender:nameDirection',
#      'parking:condition:area',
#      'parking:condition:area:customers',
#      'parking:condition:area:maxstay',
#      'parking:condition:area:time_interval',
#      'parking:condition:both',
#      'parking:condition:both:1',
#      'parking:condition:both:1:residents',
#      'parking:condition:both:2',
#      'parking:condition:both:2:ticket',
#      'parking:condition:both:2:time_interval',
#      'parking:condition:both:capacity',
#      'parking:condition:both:default',
#      'parking:condition:both:maxstay',
#      'parking:condition:both:residents',
#      'parking:condition:both:time_interval',
#      'parking:condition:both:type',
#      'parking:condition:both:vehicles',
#      'parking:condition:left',
#      'parking:condition:left:1',
#      'parking:condition:left:1:maxstay',
#      'parking:condition:left:1:residents',
#      'parking:condition:left:1:ticket',
#      'parking:condition:left:1:time_interval',
#      'parking:condition:left:2',
#      'parking:condition:left:2:ticket',
#      'parking:condition:left:2:time_interval',
#      'parking:condition:left:3',
#      'parking:condition:left:3:residents',
#      'parking:condition:left:3:time_interval',
#      'parking:condition:left:capacity',
#      'parking:condition:left:default',
#      'parking:condition:left:maxstay',
#      'parking:condition:left:residents',
#      'parking:condition:left:time_interval',
#      'parking:condition:left:type',
#      'parking:condition:right',
#      'parking:condition:right:1',
#      'parking:condition:right:1:maxstay',
#      'parking:condition:right:1:residents',
#      'parking:condition:right:1:ticket',
#      'parking:condition:right:1:time_interval',
#      'parking:condition:right:2',
#      'parking:condition:right:2:ticket',
#      'parking:condition:right:2:time_interval',
#      'parking:condition:right:3',
#      'parking:condition:right:3:residents',
#      'parking:condition:right:3:time_interval',
#      'parking:condition:right:capacity',
#      'parking:condition:right:default',
#      'parking:condition:right:maxstay',
#      'parking:condition:right:residents',
#      'parking:condition:right:time_interval',
#      'parking:condition:right:type',
#      'parking:condition:ticket',
#      'parking:lane:both',
#      'parking:lane:both:parallel',
#      'parking:lane:left',
#      'parking:lane:left:capacity',
#      'parking:lane:left:diagonal',
#      'parking:lane:left:parallel',
#      'parking:lane:right',
#      'parking:lane:right:capacity',
#      'parking:lane:right:diagonal',
#      'parking:lane:right:parallel',
#      'parking:side:left',
#      'parking:side:right',
#      'phone_1',
#      'plant:output:electricity',
#      'railway:milestone:catenary_mast',
#      'railway:milestone:emergency_brake_override',
#      'railway:position:exact',
#      'railway:signal:combined',
#      'railway:signal:combined:form',
#      'railway:signal:combined:function',
#      'railway:signal:combined:height',
#      'railway:signal:combined:marker_light',
#      'railway:signal:combined:states',
#      'railway:signal:combined:substitute_signal',
#      'railway:signal:departure',
#      'railway:signal:departure:form',
#      'railway:signal:departure:states',
#      'railway:signal:direction',
#      'railway:signal:distant',
#      'railway:signal:distant:form',
#      'railway:signal:distant:height',
#      'railway:signal:distant:repeated',
#      'railway:signal:distant:states',
#      'railway:signal:main',
#      'railway:signal:main:deactivated',
#      'railway:signal:main:form',
#      'railway:signal:main:function',
#      'railway:signal:main:height',
#      'railway:signal:main:states',
#      'railway:signal:main:substitute_signal',
#      'railway:signal:minor',
#      'railway:signal:minor:deactivated',
#      'railway:signal:minor:form',
#      'railway:signal:minor:height',
#      'railway:signal:minor:states',
#      'railway:signal:position',
#      'railway:signal:route',
#      'railway:signal:route:form',
#      'railway:signal:route:states',
#      'railway:signal:route_distant',
#      'railway:signal:route_distant:form',
#      'railway:signal:route_distant:states',
#      'railway:signal:speed_limit',
#      'railway:signal:speed_limit:form',
#      'railway:signal:speed_limit:height',
#      'railway:signal:speed_limit:speed',
#      'railway:signal:speed_limit_distant',
#      'railway:signal:speed_limit_distant:form',
#      'railway:signal:speed_limit_distant:speed',
#      'railway:signal:stop',
#      'railway:signal:stop:caption',
#      'railway:signal:stop:form',
#      'railway:signal:stop:height',
#      'railway:signal:wrong_road',
#      'railway:signal:wrong_road:form',
#      'railway:switch:electric',
#      'ref:AEFE',
#      'ref:BLfD',
#      'roof:slope:direction',
#      'service:bicycle:charging',
#      'service:bicycle:cleaning',
#      'service:bicycle:diy',
#      'service:bicycle:pump',
#      'service:bicycle:rental',
#      'service:bicycle:repair',
#      'service:bicycle:retail',
#      'service:bicycle:second_hand',
#      'shop:music:cd',
#      'shop:music:new',
#      'shop:music:second_hand',
#      'shop:music:vinyl',
#      'shop_1',
#      'sidewalk:left:smoothness',
#      'sidewalk:left:surface',
#      'sidewalk:left:width',
#      'sidewalk:right:bicycle',
#      'sidewalk:right:bicycle:oneway',
#      'sidewalk:right:foot',
#      'sidewalk:right:smoothness',
#      'sidewalk:right:surface',
#      'sidewalk:right:width',
#      'socket:type2',
#      'source:addr:housenumber',
#      'source:building:levels',
#      'source:maxspeed:backward',
#      'source:maxspeed:forward',
#      'source:roof:height',
#      'sport_1',
#      'sport_2',
#      'temporary:addr:city',
#      'toll:N3',
#      'tower:type:de',
#      'turn:lanes:backward',
#      'turn:lanes:forward',
#      'via:2',
#      'voltage-high',
#      'voltage-low',
#      'website_1',
#      'website_2',
#      'wheelchair:description:de',
#      'wheelchair:description:en'])

# %%
def process_map(filename):
    users = set()
    i = 1
    for _, element in ET.iterparse(filename):
        if element.tag in ["node", "way", "relation"]:
            users.add(element.get("user"))
        if i > 300000:
            sys.stdout.write('*')
            i = 1
        else:
            i += 1
    
    sys.stdout.write('\n') 

    return users

if True:

    users = process_map(OSM)
    pprint.pprint(users)
# Out:
# ******************
# set(['',
#      '(maxmaxmax)',
#      '0815andi',
#      '1976',
#      '2StepForward',
#      '2bogen',
#      '2weiblum',
#      '3dMartin',
#      '42429',
#      '46&2',
#      '4SeasonNL',
#      '4rch',
#      '708145',
#      '715371',
#      '7oak',
#      '80798',
#      '81825-MUC',
#      '87takeiteasy',
#      '8p1t1h',
#      '<don>',
#      'ABRob',
#      'AFeixelmeier',
#      'AadenrsSceehrr',
#      'Achterin',
#      'AdinaB',
#      'Admin UFG',
#      'AdrianDiemer',
#      'AignerImmobilien',
#      'AkiraYoshi',
#      'AlbertKa',
#      'Aleks-Berlin',
#      'Alessio Ceroni',
#      'Alexander Roalter',
#      'Alexander Rohde',
#      'AlexanderF',
#      'AlexanderNass',
#      'Almhias',
#      'Alois74',
#      'Alpin100',
#      'Amili',
#      'Amplico',
#      'Anchises',
#      'Anderl0815',
#      'AndersAndersson',
#      'AndiG88',
#      'AndiO',
#      'AndiV',
#      'Andi_Voss',
#      'Andradir',
#      'Andre68',
#      'Andre71139',
#      'AndreR',
#      'Andreas Binder',
#      'AndreasDangel',
#      'Andrey Korolyov',
#      'AnkEric',
#      'Anna_annA',
#      'Anoniman',
#      'Anteru',
#      'Antig',
#      'Anton Werner',
#      'AppStore',
#      'Armin Pollak',
#      'ArnoNym',
#      'Arthur Lorenz',
#      'Ascher_k',
#      'Aschilli',
#      'Audio',
#      'Aufhax',
#      'Augustus Kling',
#      'Aury88',
#      'Autanius',
#      'Axel Jagemann',
#      'Axelf',
#      'Axterix',
#      'B-i-n-h-o',
#      'BBMike',
#      'BBO',
#      'BBWi',
#      'BGL',
#      'BJ-Axel',
#      'BR0SI',
#      'BSCMoosach',
#      'BakerM4n',
#      'Bardo Nelgen',
#      'Barfly_MB',
#      'Barnie',
#      'BartelWP',
#      'Baschti',
#      'Basstoelpel',
#      'BauerT21',
#      'BavariaMotel',
#      'Bayern_Radler',
#      'Bayerwald',
#      'BeJay',
#      'BeJotEl',
#      'BeKri',
#      'BearT',
#      'Ben1703',
#      'Bengatzer',
#      'Benne86',
#      'Berenice1',
#      'Berimbau21',
#      'BernLoh',
#      'Bernd Konnerth',
#      'BerndW',
#      'Bernd_BDP',
#      u'Bernhard_M\xfcnchen',
#      'Bert_muc',
#      u'Berufsbildungswerk M\xfcnchen',
#      'BiIbo',
#      'Biff',
#      'BigBen2003',
#      'Bike_S',
#      'Black-Eyed Lion',
#      'Blatschuss',
#      u'BlaueBl\xfcte',
#      'BlueKnight1970',
#      'Blueriderlight',
#      'Bluminger',
#      'Bohnix',
#      'Bomapius',
#      'Boobarkee',
#      'Boris2011',
#      'Boris_MVV',
#      'Borstellino',
#      'Brainlessnick',
#      'Bratananio',
#      'Bratix',
#      'Bravier',
#      'Brian@Brea',
#      'Broky',
#      'BrollyLSSJ',
#      'BrunoCC',
#      'Bryce C Nesbitt',
#      'BugBuster',
#      'BuganiniQ',
#      'Bullroarer',
#      'BungaBunga',
#      'Buntepixel',
#      'Burgerfelder',
#      'BurninLeo',
#      'BurnyB',
#      'Buschmann',
#      u'B\xe4rli',
#      'C4B',
#      'CADdy123',
#      'CK-85622',
#      'CNelke',
#      'CTFMoN',
#      'Californiaspyder',
#      'Cambodia-mapper',
#      'Camper',
#      'CaptainCrunch',
#      'Carla Singer',
#      'Carola Mletzko',
#      'Catweazle2011',
#      'Cerritus',
#      'ChArmin',
#      'Champ0815',
#      'Chaosqueen',
#      'Chaot2010',
#      'Charisma',
#      'Charley San',
#      'Chemist72',
#      'Chire',
#      'Chris-He',
#      'Chris4549',
#      'ChrisTheMapper',
#      'ChrisWe',
#      'ChrissW-R1',
#      u'Christian K\xf6stlin',
#      'Christian Weller',
#      'Christof_MUC',
#      'Christoph H',
#      'Christoph Lotz',
#      'Christoph S',
#      'Christoph Thomas',
#      'Christopher',
#      'Chrsgr',
#      'Chumwa',
#      'Ciax Stark',
#      'Cipio',
#      'Citysleepers',
#      'Clark2309',
#      'Claudius Henrichs',
#      'Cloonix',
#      'CmdrFirewalker',
#      'Cnny',
#      'Cobra',
#      'CodingSpace',
#      'ConsEbt',
#      'Constl',
#      'Creando',
#      'Cryptoworld',
#      'Curly Biggelow',
#      'DD1GJ',
#      'DN1NX',
#      'DS2010',
#      'DSkywalker',
#      'Da Sam',
#      'DaBear',
#      'DaGerba',
#      'Dahie',
#      'Dakon',
#      'Dan-yell',
#      'DanX',
#      'DangNgu',
#      'Daniel Rosigkeit',
#      'Daniel Weinfurtner',
#      'Daniel27',
#      'Daniel632',
#      'Daniel99',
#      'Danieltu',
#      'Daschifahrer',
#      u'Dauerl\xe4ufer',
#      'David Crochet',
#      'DavidP',
#      'Davio',
#      'Delliwood',
#      'DennisL',
#      'Denyo',
#      'Der Harry',
#      'DerAdel',
#      'DerElch',
#      'DerFlob',
#      'DerMoment',
#      'Derk Muenchhausen',
#      'Devran Uenal',
#      'Dibaus',
#      'Dieter Schmeer',
#      'Dinamik',
#      'Dirk325',
#      'Division',
#      'Djack',
#      'DomiRS4',
#      'Domo96',
#      'Don Kostino',
#      'Don24',
#      'DoubleA',
#      'Dr Kludge',
#      'DrScott',
#      'Drea58',
#      'Drillman-1',
#      'Duckula',
#      'Dwi Secundus',
#      'DwyaneWade',
#      'Dyse',
#      u'D\xfcnenst\xfcrmer',
#      'E-Malte',
#      'EDDM',
#      'EDSM Felix 2012',
#      'EJ_',
#      'ENORMA',
#      'ETH',
#      'EaSY',
#      'EastTX',
#      u'Eckhart W\xf6rner',
#      'EcoRI',
#      'EffKay_muc',
#      'Einradtrialer',
#      'ElChefe',
#      'ElDiabolo',
#      'Elmi77',
#      'EmilioZ',
#      'EricSander',
#      'Erotic Dreams',
#      'Essimo',
#      'Estartu',
#      'Eugen Neufeld',
#      'F2-Beamer',
#      'FFGR_1',
#      'FFHohenbrunn2',
#      'FKn',
#      'Fabi2',
#      'Fabimaru',
#      'Fabue',
#      'FahRadler',
#      'Falk Fleischer',
#      'Fasanenchris',
#      'FastNetterMuc64',
#      'Feetz',
#      'Ferengi',
#      'Feu',
#      'Fido OSM',
#      'Filius Martii',
#      'Filius Martii MDV',
#      'FinnJapan',
#      'FishermansFriend',
#      'Fivon',
#      'Flarki',
#      'Flo Sorg',
#      'FloLi',
#      'FloSch',
#      u'FloSpie\xdf',
#      'Flobe',
#      'Floppy919',
#      'FloriS1982',
#      'Florian Listl',
#      'FlorianXolf',
#      'Flose',
#      'Flutus',
#      'Flynsch',
#      'Foehni',
#      'Fori',
#      'Forscher56',
#      'Forsttrack',
#      'Fotoportal',
#      'FrViPofm',
#      'Fraeggl',
#      'Fraeggl666',
#      u'Frage der Mobilit\xe4t',
#      'Francesco Pasa',
#      'Frank1958',
#      'FrankU112',
#      'Franz-',
#      'Franz68',
#      'FranzP',
#      u'Fran\xe7ois Blondel',
#      'FrauHoth',
#      'FredAnna2',
#      'FredFerdi',
#      'Fredl Eglfing',
#      u'Friedrich M\xfcller (Necromonger)',
#      'Friesheim',
#      'Fritz210',
#      'Fuhrmann',
#      'Funzi',
#      'Fuss-im-Ohr',
#      'FvGordon',
#      'GPSMAP62S',
#      'GRUBERND',
#      'GS25',
#      'GabCar',
#      'Gafzgarrr',
#      'Galgi',
#      'Ganzegal',
#      'Garmin-User',
#      'Garmin765T',
#      'Garminger',
#      'Gavaasuren',
#      'Gehrke',
#      'Gellule',
#      'Geo-OSM',
#      'Geo-Tobi',
#      'Geofalke',
#      'Geogast',
#      'Geophil',
#      'Georg13',
#      'Gerd Badur',
#      'Gerhard Meier',
#      'Gerhardt Hueck',
#      'Gerit Wagner',
#      'Gerlingen94',
#      'Gilbert Agathon Hawks',
#      'Giszmo',
#      'Glenn Plas',
#      'Glg11',
#      'Glopus',
#      'Gluko',
#      u'Gl\xfccki',
#      'Gobelix',
#      'Godik',
#      'Gogglehead',
#      'Gogul',
#      'Gorgo',
#      'Gorgonz',
#      'Gotthilf',
#      'GpsWandern',
#      'Granjow',
#      'Greggy22',
#      u'Gregor M\xfcllegger',
#      u'Gr\xfcner Flip',
#      'Gsichtgsicht',
#      'Guenni',
#      'Gustl99',
#      'Gusto4711',
#      'Gutergrieche',
#      'Guty',
#      'HBR',
#      'HCX Biker',
#      'HHCacher',
#      'HaZet',
#      'Hadmut',
#      'HaegarHo',
#      'Haenfling',
#      'HampelZamba',
#      'Hanki',
#      'HannesV',
#      'Hans Loderer',
#      'HansJ',
#      'HansS',
#      'Hans_H',
#      'Harald Hartmann',
#      'HarryCam',
#      'Harti',
#      'Hartmut Holzgraefe',
#      u'Hauke M\xfcller',
#      'Haves',
#      'Hedaja',
#      'Heia',
#      'Heideammer',
#      'Heiko Kanz',
#      'Heino Lengfelder',
#      'Helferlein2012',
#      'HelgeJ',
#      'HellasY',
#      'Helmut Kauer',
#      'HenningS',
#      'Henrik-B',
#      'HenryLoenwind',
#      'HenryV',
#      'Herbert Hantelmann',
#      'Herbert167',
#      'Herbert3',
#      'HerrAdams',
#      'HerrKaiser',
#      'Heupgen Urban',
#      'Hike39',
#      'Hilton Worldwide',
#      'HintQuest',
#      'HolgerJeromin',
#      'Holgr',
#      'Holly1',
#      'HoloDuke',
#      'Homer-S',
#      'Hubsi',
#      'Hund007',
#      'Huy Dinh',
#      'IMG GmbH',
#      'I_codemonkey',
#      'IbnAli',
#      'Ich_hasse_doitsche_OSM-Korinthenkacker',
#      'Idealist',
#      'InfoPlease',
#      'IngoWichmann',
#      'IngoZahn',
#      'Innenarchitekt - Anetseder',
#      'Internethias',
#      'Irrfahrt',
#      'Iskender Uyar',
#      'Islanit',
#      'ItsAnja',
#      'Ivan Belchev',
#      'Ivo Schwan',
#      'Ivolino',
#      'JDM',
#      'JIDB',
#      'JJ Rammerl',
#      'JMK247W',
#      'JND',
#      'JPG',
#      'JR_JR_JR',
#      "Jacob's-Staff",
#      'Jaddar',
#      'JakovSamsonov',
#      'JamesB',
#      'Jan Hermelink',
#      'Jan Jesse',
#      'JanCBorchardt',
#      'Jano John Akim Franke',
#      'Jaro',
#      'Jassi85',
#      'Javierpf',
#      'JayJay88',
#      'Jedrzej Pelka',
#      'Jeffrey Ratcliffe',
#      'Jemma',
#      'Jens P',
#      'JensemannWF',
#      'Jessy',
#      'Joachim_K',
#      'Jochen Topf',
#      'Jodaa',
#      'Jody SEC',
#      'JohanWJoubert',
#      'Johannes Knarr',
#      'Johannes123',
#      'JohnDoe23',
#      'Johnny Carlsen',
#      'Jojo4u',
#      'Jok321',
#      'Josef73',
#      'JosmJo',
#      'JueHo',
#      'Juergen Frank',
#      'Juha H',
#      'Julian Kranz',
#      'Julian Wergieluk',
#      'Junuz',
#      'Justafchen',
#      u'J\xf6rg Dietrich',
#      u'J\xf6rg Ostertag',
#      u'J\xf6rg Schulz',
#      u'J\xf6rgBNN',
#      'K-McNeill',
#      'K-Stefan',
#      'KPG',
#      'Kaefer84',
#      'Kaffeebohne',
#      'Kai-Uwe123',
#      'Kai1963',
#      'KaiHH',
#      'KaosKatte',
#      'Kaos_di',
#      'Kap Horn',
#      'KarstK',
#      'KartoGrapHiti',
#      'Katharina Abel',
#      'Katharina88',
#      'Keigan',
#      'Keloglan',
#      'KerLeone',
#      'Kerstin76',
#      'KerstinSchmidt',
#      'Kickeriki23',
#      'KiwiMoe',
#      'Klaus-Geo',
#      'Klaus-Heinz Herda',
#      'KlausG',
#      'KlausMuc',
#      'Klinker',
#      'Kluex',
#      'Kmiki87',
#      'Knipperdollinck',
#      'Knottenfresser',
#      'Kommissar',
#      'KonB',
#      'Krischi71',
#      u'Krte\u010dek',
#      'Krustyyy',
#      'Kurly',
#      'Kurmis',
#      'Kurt34',
#      u'K\u0430\u0440\u0442\u043e\u0433\u0440\u0430\u0444\u043e\u0432',
#      'L-Klitschi',
#      'LCRalf',
#      'LEIDRCAR',
#      'LPGR',
#      'LSimedo',
#      'LXS',
#      'LaUltima',
#      'LaimerStreet!',
#      'Larifari77',
#      u'Lauche & Maas M\xfcnchen',
#      'LauraPinter',
#      'Laurin _003',
#      'LdZ',
#      'Leone',
#      'LeonidasDE',
#      'Leoss',
#      u'Le\xf8',
#      'Lichtgestalt',
#      'LifeDesign',
#      'LifeScienceCampus',
#      'Lili Junker',
#      'Line aus Muc',
#      'Linnet',
#      'Linus',
#      'Linutux',
#      'Linux',
#      'Little Brother',
#      'LocutusB',
#      u'Lokverf\xfchrer',
#      'LordNelson',
#      'Lorenz Krapp',
#      'Lulu-Ann',
#      'Lyda',
#      'Lysathor',
#      u'L\xfcbeck',
#      'M i c h a e l',
#      'M4n!',
#      'MD1',
#      'MDel',
#      'METLCA',
#      'MH26',
#      'MH89M',
#      'MKEMKE',
#      'MKnight',
#      'MLeidolph',
#      'MMR1988',
#      'MMol',
#      'MPuls',
#      'MSC4646',
#      'MaAnLa',
#      'MaNockenberg',
#      'MaO1961',
#      'MaPill',
#      'Maarten Deen',
#      'Madonius',
#      'Mafeu',
#      'Mailinator3211',
#      'Mama8',
#      'Manu1400',
#      'MapMuck',
#      'MapUserOne',
#      'MappingDan',
#      'Marco Schuster',
#      'Marcus Wolschon',
#      'MarcusLS',
#      'Marguth',
#      'Marianne Busch',
#      'Marion Geiger',
#      'Marius Dobrin',
#      'MarkGreene',
#      'Markellan',
#      'Markus K',
#      'Markus Matern',
#      'Markus59',
#      'Markus79',
#      'Marqqs',
#      'Marsupium',
#      'Martin Huber',
#      'Martin Larcher',
#      'Martin von Gagern',
#      'MasiMaster',
#      'Maskulinum',
#      'Math1985',
#      'Mathbau',
#      'Matthias Frank',
#      'Matthias Wolf',
#      'MatthiasKabel',
#      'MatthieuMartin',
#      'Maturi0n',
#      'Maui Muc',
#      'Max Maurer',
#      'Max Vasilev',
#      'Maxim Tkachov',
#      'Maximum',
#      'McDulla',
#      'McRosebuttlejam',
#      'Meckstar',
#      'Meckymesser',
#      'Med',
#      'Meier',
#      'Meinereiner',
#      'Meinert',
#      'MeisterLambda',
#      'Melmuc',
#      'MentzDV',
#      'Mentzdv_ML',
#      'Merlin2013',
#      'Meskalin',
#      'MetalMarcus',
#      'Metatron22',
#      'Metrax',
#      'Metrax84',
#      'Michael "Erwin"',
#      'Michael Dietze',
#      'Michael Forster',
#      'Michael Gusev',
#      'Michael Kanis',
#      'Michael Seiffert',
#      'Michael Spitzenberger',
#      'Michael Zemanek',
#      'MichaelJRath',
#      'MichaelK',
#      'MichaelMuehlhaus',
#      'Michael_H',
#      'Michaelw',
#      'Michi',
#      'MichiM',
#      'Midas',
#      'Miguel Andrade',
#      'Miguel0777',
#      'Mike FABIAN',
#      'Mikeybert',
#      'Mikroprofessor',
#      'Mimosin',
#      'Mison',
#      'Mitooo',
#      'Mloni',
#      'Moatl',
#      'Mobile Software AG',
#      'Mojopuegogo',
#      'Molker',
#      'Molze',
#      'Monaco',
#      'Monaco Flo',
#      'Monthyprada',
#      'Moo5osiew6',
#      'Moritz Fischer',
#      'Morky',
#      'Mostafa Fouly',
#      'MrBean',
#      'MrRoute',
#      'MrWebber',
#      u'MrsK\xf6ngen',
#      'MtbAnderl',
#      'MucHans',
#      'Mucbarney',
#      'Mueller Thomas Grainau',
#      'Mykhaylo-Munch',
#      'MysticFire',
#      'NE2',
#      'NUP',
#      'Nadjita',
#      'Nailix',
#      'Nakaner',
#      'Nakaner-repair',
#      'Nana Ma',
#      'Naumburger',
#      'Nautic',
#      'Negger',
#      'Neo777',
#      'NeoVanGoth',
#      'NepoMUC69',
#      'Nerobuster',
#      'Netzwolf',
#      'Nicewood',
#      'Nicky',
#      'NicoDuevelmeyer',
#      'Nightdive',
#      'Nina Burkart',
#      'NinaNo1',
#      'Nirata',
#      'Nitro_Joe',
#      'NoL',
#      'Nop',
#      'Nora Schiffer',
#      'Norbert18',
#      'Nordpfeil',
#      'NotBob',
#      'Nuttha Beam Sirilertworakul',
#      'OCTALIS',
#      'ODanione',
#      'OSMF Redaction Account',
#      'OSMNom',
#      'OSMTUM',
#      'Obelixx',
#      u'Oberf\xf6rster',
#      'Odysseus-DPB',
#      'Ogmios',
#      'OhWeh',
#      'Okri',
#      'Olaf312',
#      'Oli-Wan',
#      'OliverLondon',
#      'Omikron1987',
#      'OmikronXi',
#      'OnSerious',
#      'Opeloli',
#      'OpenBeerMapContributor',
#      'OpenSamyMap',
#      'Oscar Goldmann',
#      'Osmose',
#      'Ossi58',
#      'Ottifanti',
#      'Ottonormalverbraucher',
#      'PAule666',
#      'PHerison',
#      'PKR73',
#      'PWolf',
#      'PacoMenem',
#      'Pahu666',
#      'Pai Peng',
#      'Palacios',
#      'Paletti',
#      'Papierrestaurator',
#      'Paross',
#      'Patchi',
#      'Patrick Blume',
#      'Patrick Funke',
#      'PatrickK',
#      'PatrickKaufmann',
#      'Paul Johnson',
#      'Paulchen Panther',
#      'Paulest',
#      'PawelJ',
#      'PeetTheEngineer',
#      'Pegasus',
#      'Peilscheibe',
#      'Peppschmir77',
#      'Pert567',
#      'PeteOSM',
#      'Peter Maiwald',
#      'Peter14',
#      'PeterDRS',
#      'PeterMO',
#      'PeterPablo',
#      'Phil0x',
#      'Phil567',
#      'Philipp Kern',
#      'Philipp Koch',
#      'Phillipp Huber',
#      'Phobon',
#      'Photogenika',
#      'PiJ82',
#      'Pinback',
#      'Pinsler',
#      'PolarbaerHH',
#      'Polarbear',
#      'PoloAkaShoxX',
#      'Polorium',
#      'PonPan',
#      'Popiesch',
#      'Pucki85',
#      'Punitor',
#      'Purzel69',
#      'Pyrokrat',
#      'Q12',
#      'QSTE380TM',
#      'Qantor',
#      'Quelbs',
#      'Quinn McArthur',
#      'Quirin',
#      'R0bst3r',
#      'RC23',
#      'RFV Prien',
#      'RM87',
#      'RZ1412',
#      'RadFr',
#      'Radeln',
#      'Radu_i',
#      'RafaelNK',
#      'Rafael_M',
#      'RaftaMan',
#      u'Raiffeisenbank M\xfcnchen-S\xfcd eG',
#      'Railmaster',
#      'Rainer Jung',
#      'Rainermuenchen',
#      'Rainero',
#      'Ralf Eichler',
#      'RalfZ',
#      'Ralph71',
#      'RandySchwartz',
#      u'Raul Gr\xfcnbau',
#      'RedHering01',
#      'RedStripe',
#      'Redeal',
#      'Rene Westerholt',
#      'Rennbert',
#      'Retz',
#      'ReverendMapJoy',
#      'Rian76',
#      'Rich Maier',
#      'RichRico',
#      'RichardHesse',
#      'RichardRapid',
#      'RicoZ',
#      'RoSe',
#      'RoXus',
#      'RobKl',
#      'Robert Whittaker',
#      'Robiston',
#      'Robotrino',
#      'RoccoGrande',
#      u'Rodolphe Qui\xe9deville',
#      'Rogehm',
#      'Roger Duncan',
#      'RolandS',
#      'RolfAlto',
#      'Roman',
#      'Roman Tikhonov',
#      'Ropino',
#      'Rosiv Damotil',
#      'Rossner',
#      'Rosty',
#      'Rudolf Mayer',
#      'Rumpeltux',
#      'S-laeuft',
#      'SAS6667',
#      'SBjoern',
#      'SHLTK',
#      'SKu_DeM',
#      'SPTH',
#      'SRE_FMS_HE',
#      'SRE_I_A_Omm',
#      'Sabine Runge',
#      'SabineSW',
#      'Sadhu',
#      'Sammelmuetze',
#      'Samsemilio',
#      'Samuel Borsutzky',
#      'Samux',
#      'Sandweg',
#      'Sascha48',
#      'Saurus',
#      'Scharri',
#      'Schdrizi',
#      'Schlenner Karl',
#      'Schlomo Impel',
#      'Schlung',
#      'Schlusie',
#      'Schlux',
#      'SchoMuc',
#      'Schoos',
#      'Schufulupiplu',
#      'Schupfi',
#      'Schusch',
#      'SchwartzKS',
#      'Seandebasti',
#      'Sebastian Schmidt',
#      'SebiMuc',
#      'Seeer',
#      'Seetroll',
#      'Segeln',
#      'Semmel Huber',
#      'SennaHB',
#      'Serendipity1110',
#      'Sergey Borodavkin',
#      'Serpens',
#      'Sers',
#      'Sgop',
#      'Shahin Sharifi Noorian',
#      'Sharlin',
#      'ShaunMundy',
#      'Shri S V',
#      'Sicaine',
#      'Siegbaert',
#      'Sigi Reich',
#      'Silanea',
#      'SimonPoole',
#      'SimonSa',
#      'Simontawan',
#      'Simploni',
#      'Singing-Poppy',
#      'Singvogel',
#      'Sipple',
#      'Sir2B',
#      'Skombi',
#      'Skruppy',
#      'Skubiduhh',
#      'Skyman',
#      'Skymaster',
#      'Skywave',
#      'Slaryn',
#      'SmartVet',
#      'Smartandem',
#      'Smurftrooper',
#      'Snooker147',
#      'Snoopy88',
#      'So happy!',
#      'Soave',
#      'Socke555',
#      'Soldier Boy',
#      'SoulCover',
#      'SpieleHolger',
#      'Spieltag',
#      'SpiritOfPhotography',
#      'Spongilla',
#      'Spoony',
#      'Spunk_Tom',
#      'Spunsel',
#      'Spywar3',
#      'Stadtradler',
#      'Stef99',
#      'Stefan Liebl',
#      'Stefan1970',
#      'StefanKa',
#      'StefanMTB',
#      'StefanST',
#      'Stefanf74',
#      'Steffilein',
#      'StephOSM',
#      'Stereo',
#      'Stevey',
#      'Strauch_Steine_Erden',
#      u'Stra\xdfenbauer',
#      'StreitAlbert',
#      'StuP',
#      'StudeBakerAE86',
#      'Subidux',
#      'Suchhund',
#      'SukaNo1',
#      'SurveyAlex',
#      'Susan Steinhoff',
#      'SveLil',
#      'Sven Anders',
#      'Sven Lilienthal - Upload',
#      'SvenR',
#      'Swapingo',
#      'Syl',
#      'Sympher',
#      'Systemfehler_Muc',
#      'T3QU1LA',
#      'TCMary',
#      'THRA',
#      'THansen3',
#      'TKKU',
#      'TMCbot',
#      'TMarwL',
#      'TZorn',
#      'Tabaluga99',
#      'Tabularaza',
#      'Tazi',
#      'Teddy80',
#      'Terencehill',
#      'Test360',
#      'TestSkizze',
#      'Tetman',
#      'Thalandor2000',
#      'TheBaron',
#      'TheFive',
#      'TheNam3less',
#      'TheTruth',
#      'TheWorldAccording2Matt',
#      'The_Mappet_Show',
#      'TheaGe',
#      'Theodin',
#      'Thomas Gabelmann',
#      'Thomas Kregelin',
#      'Thomas8122',
#      'ThomasHGM',
#      'ThomasSteininger',
#      'ThomasStr',
#      'ThomasT',
#      'Thomasmueller',
#      'ThommThomm',
#      'Thomzen',
#      'TigerDuck',
#      'Tilemann',
#      'Tiram',
#      'Tiramisu',
#      'Tiyzery',
#      'Tizianos',
#      'ToB',
#      'TobHaeg',
#      'Tobi-rr',
#      'Tobi-wankenobi',
#      'TobiSto',
#      'Tobias Meyer',
#      'Tobiby',
#      'Todeskuh',
#      'Toliman',
#      'TomRadfahrer',
#      'Tomi-Toma',
#      'Tomst3r',
#      'ToniE',
#      'Toni_by',
#      'Tonno67',
#      'Topthor',
#      'Torkel',
#      'Touraner',
#      'TrafficJam',
#      'Trallali',
#      u'TrekBicycleStoreM\xfcnchen',
#      'Trex2001',
#      'Triggonaut',
#      'Trinitor',
#      'Troels Arvin',
#      'Tromse',
#      'Tronikon',
#      'Truchtaro',
#      'Truquete',
#      u'Tsch\xe4fer',
#      'Tshikey',
#      'Tuks',
#      'Turtur',
#      'TzA',
#      'UMS_Team',
#      'USSEraser',
#      'UknownTerritory',
#      'Ulfe',
#      'Ultimo1000',
#      'Ulwald',
#      'Unic-com',
#      'Uranoxyd',
#      'Urobe',
#      'Uwe Ewald',
#      'Uwe Martin',
#      'VARTA',
#      'VBehrends',
#      'VSWR99',
#      'Vab95',
#      'Vegel',
#      'VeloM',
#      'VeloRoadster',
#      'Verdy_p',
#      'Victor Kropp',
#      'VictorTerber',
#      'Voice01',
#      u'Volker Fr\xf6hlich',
#      'Vral',
#      'WLG',
#      'WagnerP',
#      'Waldgarten',
#      'Waldrenner',
#      'Waldschraat',
#      u'Wall\xb7E',
#      u'Walter Schl\xf6gl',
#      'WaltherSparbier',
#      'WanMil',
#      'Warden',
#      'Waste1',
#      'WebReaper',
#      'WegefanHB',
#      'Weide',
#      'Weltenbummler',
#      u'Werner Schulthei\xdf',
#      'WernerP',
#      'Werner_G',
#      'Willem@Scout24',
#      'Willhelm_Mueller',
#      'Win32netsky',
#      'WinfriedHuber',
#      'Witte4osm',
#      'Wixii',
#      'WolfFisch',
#      'Wolfram Sobotta',
#      'Wolthusen',
#      'WosuGer',
#      'Wuermtalkartograf',
#      'Wurzelzwerg22',
#      'XM-Franz',
#      'XlF42',
#      'Xonx140922',
#      'Xylem',
#      'Yrrlicht',
#      'ZZ29',
#      'ZaaZoo',
#      'Zartbitter',
#      'Zauberertz',
#      'Zawusel',
#      'Zeitlupe',
#      'Zeno Kugy',
#      'ZooL',
#      'Zordid',
#      'Zrkr',
#      '[NzN]suriv',
#      '[]+[]',
#      '_Donald_',
#      '_Lutz_',
#      '_anon_',
#      '_rigid',
#      'a3vanka',
#      'a6unadh',
#      'abcd123',
#      'abel801',
#      'ablacky',
#      'abrax5',
#      'abunai',
#      'ac201',
#      'acbauer',
#      'account_deleted_1011',
#      'aceman444',
#      'achims311',
#      'acmecorp',
#      'adi_z',
#      'adirricor',
#      'adjuva',
#      'adresser',
#      'adrex',
#      'aeroflo',
#      'afiesselmann',
#      'aguentsch',
#      'aighes',
#      'ajeba',
#      'ajoessen',
#      'akoppstein1',
#      'aleistner',
#      'alester',
#      'alex-map',
#      'alexander rober kroll',
#      'alexander2010',
#      'alexander_behring',
#      'alexrudd',
#      'alexrye',
#      'alinda',
#      'aliponte',
#      'alpe3',
#      'alpengondoliere',
#      'amids',
#      u'andereb\xe4r',
#      'anderlEDDM',
#      'andirun',
#      'andreaslrchr',
#      'andrewpmk',
#      'andromedar',
#      'andwin',
#      'andy1010001',
#      'andygol',
#      'anec',
#      'angrox',
#      'ansans',
#      'antabeer',
#      'ap-KF',
#      'aps',
#      'apus_apus',
#      'aquinanar',
#      'arkv',
#      'art-and-piano',
#      'artworkcompany',
#      'arx',
#      'asbiot',
#      'aschauerf',
#      'aseerel4c26',
#      'asish012',
#      'astfaellergerald',
#      'astravis75',
#      'atest',
#      'aufgleiser',
#      'aukue',
#      'avanka',
#      'avatar',
#      'avus',
#      'axelr',
#      'azet',
#      'baer2006',
#      'baerenmarder',
#      'baghira42',
#      'bahnpirat',
#      'baily',
#      'bakamu',
#      'bangla',
#      'barista-b',
#      'bastibay',
#      'bauer-muenchen',
#      'baum9076',
#      'bavariastudios',
#      'beazba',
#      'bedouine2012',
#      'befega',
#      'begruber',
#      'beisickl',
#      'benAtNetz',
#      'benelsen',
#      'benep',
#      'benhurxt',
#      'benno63308',
#      'bentobecker',
#      'bergfex',
#      'bergfex1975',
#      'bergfex42',
#      'bergzeit',
#      'bernd lauert',
#      'bernhard86',
#      'bernie123',
#      'bertman83',
#      'beweta',
#      'bfw',
#      'bib',
#      'biergartenguide',
#      'biffe',
#      'big-thought',
#      'bigalxyz123',
#      'bigbug21',
#      'bigjj13',
#      'bikemike',
#      'bilyidol',
#      'bison166',
#      'bjoern_m',
#      'black_bike',
#      'blattms',
#      'blueSHIFT',
#      'bluenose',
#      'bluestone712',
#      'bmwklaus',
#      'boerni-erlangen',
#      'bogenhausener',
#      'bohli',
#      'booo',
#      'botticchio',
#      'brainmue',
#      'brichtoteles',
#      'bridgeburner',
#      'britschler',
#      'broesel911',
#      'brunos',
#      'bsa01',
#      'bsonic',
#      'bstegmaier',
#      'btrs',
#      'bubbel',
#      'buerobaldham',
#      'bugman',
#      'buhao75',
#      'bunkr',
#      'burnus',
#      'burt13de',
#      'burts',
#      'bvivi',
#      'c0bRa',
#      'cMartin',
#      'ca-to',
#      'cachapa',
#      'cagedBird',
#      'calestyo',
#      'calfarome',
#      'cali-mera',
#      'calvin-gr',
#      'cantullus',
#      'captain_slow',
#      'captainuni',
#      'cartinus',
#      'carwill',
#      'cb013',
#      'cck',
#      'cedro',
#      'cepuros',
#      'cerigo',
#      'cesail',
#      'cfaerber',
#      'cgommel',
#      'cgu66',
#      'chan',
#      'changchun_1',
#      'changke',
#      'charta42',
#      'chas678',
#      'cheesy3000',
#      'chefkartograph',
#      'chequa',
#      'chkr',
#      'choess',
#      'chris_erik',
#      'chrischamuc',
#      'chrisfish',
#      'chrisshu',
#      'chrissibo',
#      'christcl',
#      'christian-ko',
#      'christian_liss',
#      'chrsitof',
#      'chwirsing',
#      'cinamon112',
#      'ck3d',
#      'ckm',
#      'ckol',
#      'ckoppelt',
#      'claudio_arrau2',
#      'clearman',
#      'clemenszivi',
#      'clic',
#      'clkempe',
#      'clownie',
#      'cmh_germany',
#      'cmif4',
#      'cmohrki',
#      'cmuche',
#      'cn0MMnb',
#      'cng-stations',
#      'coeibu',
#      'cogweg',
#      'colonia',
#      'comeneserse',
#      'commsrvr',
#      'compton',
#      'contargo_pjn',
#      'copycat2300',
#      'coregonus',
#      'corrados',
#      'cosmicadi',
#      'cosmosmedia',
#      'couchmapper',
#      'cpcgm',
#      'cqqcqq',
#      'cr4y',
#      'crasu',
#      'cruz',
#      'crwk',
#      'cvdr',
#      'cxm',
#      'cyb4',
#      'cyclemichael8',
#      u'c\xfcper',
#      'd65',
#      'd_s_e',
#      'dadomme',
#      'daganzdaanda',
#      'dagobertdax',
#      'dandyVN',
#      'danidoedel',
#      'danielpoehler',
#      'danillo',
#      'dannykath',
#      'dansel',
#      'darius83',
#      'dark horse',
#      'darkvision',
#      'daunentreu',
#      'dave_trasher',
#      'david_s_17',
#      'daviesp12',
#      'db54',
#      'dbusse',
#      'ddbk',
#      'deepblue66',
#      'defiantShaun',
#      'degernfelder',
#      'delfin_6',
#      'delphin1965',
#      'deltabrasil',
#      'deocka',
#      'der Eric',
#      'der__flo',
#      u'der_d\xf6edel',
#      'dermuella',
#      'deskler',
#      'dforsi',
#      'dgitto',
#      'didi86',
#      'dino_h',
#      'dirk86',
#      'dirkolus',
#      'dirska',
#      'diskostu',
#      'dittberner',
#      'dk1ri',
#      'dkiselev',
#      'dkj',
#      'dmanske',
#      'dmauz',
#      'dmo60',
#      'dmo84',
#      'doak',
#      'domob',
#      'don-vip',
#      'dooley',
#      'doremite',
#      'dragonjoe',
#      'drkeller',
#      'drohhyn',
#      'drolbr_mdv',
#      'drshaw',
#      'dsk1',
#      'dude_s',
#      'dudel17',
#      'duese',
#      'duzi',
#      'dwausr',
#      'eBin',
#      'e_m',
#      'eacym',
#      'eartrumpet',
#      'echopapa',
#      'echt',
#      'eckischeich',
#      'edaniel',
#      'ediyes',
#      'eduardosm',
#      'edwin-ldbg',
#      'efred',
#      'ehlub',
#      'eho',
#      'eimer42',
#      'elbatrop',
#      'elf Pavlik',
#      'elhennig',
#      'elm',
#      'elmoo',
#      'elsaxo',
#      'emil59',
#      'emu',
#      'enrico',
#      'entchenB',
#      'entropix',
#      'eppcag',
#      'erath',
#      'erge',
#      'eriklukacs',
#      'eriosw',
#      'erivision',
#      'erwin6330',
#      'esbjoern',
#      'essich',
#      'eston',
#      'ethmog',
#      'euronymous',
#      'evmuc',
#      'ewep',
#      'f-andreas',
#      'fahrrad',
#      'fahrradfahrer',
#      'farad',
#      'fastovskij',
#      'fdamm',
#      'feisen',
#      'felixix',
#      'felixjar',
#      'fessen+friends',
#      'ffb20fh',
#      'ffubb1',
#      'filid',
#      'fimo',
#      'fkorwes',
#      'flash2106',
#      'flierfy',
#      'flip666',
#      'flocutus',
#      'flohoff',
#      'floody00',
#      'floscher',
#      'fluder',
#      'flunschi',
#      'flupflip',
#      'flusel',
#      'fonrebin',
#      'ford_42',
#      'forfex',
#      'fpletz',
#      'francoise',
#      'franzvomsee',
#      'fred4muc',
#      'fredero',
#      'freeflow',
#      'fricus',
#      'friede',
#      'friesede',
#      'frnksnck',
#      'frosch',
#      'ftak',
#      'fuchsjaga',
#      'fuchur1984',
#      'fuettyi',
#      'fumarol',
#      'furban',
#      'fx99',
#      'fxx2000',
#      'g0ldfish',
#      'gaga80',
#      'gaia21',
#      'galadhdil',
#      'gandi',
#      'gapt',
#      'gastromat',
#      'gekkox',
#      'gemiwi',
#      'geo-francis',
#      'geoMILLImeter',
#      'geo_linux',
#      'geoabc',
#      'geodreieck4711',
#      u'geod\xf6t',
#      'geofabrik_infas_import',
#      'geohiker2010',
#      'georginakirrin',
#      'geospatialist',
#      'geozeisig',
#      'gerd95',
#      'gerhard911',
#      'gerhardl',
#      'gernot',
#      'gewald',
#      'gf2009d',
#      'gfecba',
#      'ghostrider111',
#      'gibos',
#      'giggls',
#      'gileri',
#      'girschik',
#      'girus',
#      'gkai',
#      'glaucko',
#      'gleissmap',
#      'gmhofmann',
#      'gnocchi01',
#      'gnopph',
#      'gogeo',
#      'gola_lend',
#      'golider',
#      'googler25',
#      'gormur',
#      'grafingmapper',
#      'grass_and_green',
#      'greatfrog',
#      'greecemapper',
#      'grigun',
#      'gruban',
#      'grumbier',
#      'grungelborz',
#      u'gr\xfcnschn\xe4bel neuried',
#      'gscholz',
#      'gsperb',
#      'gspring',
#      'guechr',
#      'guegafue',
#      'gulp21',
#      'gumul',
#      'gurkmaster',
#      'gynmc',
#      'gypakk',
#      'h-j-k',
#      'habuh',
#      'hacklstegga',
#      'haheigl',
#      'hairraiser',
#      'hajo',
#      'ham',
#      'hansemann1234',
#      'hansmunich',
#      'happyraul',
#      'harfner',
#      'harry6464',
#      'hasenrahml',
#      'hasibobe',
#      'hasienda',
#      'hasse_osm_korinthenkacker',
#      'hatzfeld',
#      'haudegen07',
#      'haytigran',
#      'hca',
#      'hcy',
#      'hd_andreas88',
#      'hdrewes',
#      'hdus',
#      'heavygale',
#      'hefee',
#      'hegel1770',
#      'heilbron',
#      'heimdall-m',
#      'heinzos',
#      'hejoa',
#      'heko2',
#      'helm',
#      'henki75',
#      'henryt',
#      'herbstduft',
#      'herr_blaschke',
#      'hiaciame',
#      'hibbelig',
#      'highpotential',
#      'hirmon',
#      'hirnkastl',
#      'hirtem',
#      'hmh',
#      'hobbsch',
#      'hobhaltdeimaul',
#      'holger74',
#      'holger_l',
#      'holgis',
#      'hongakonga',
#      'honkstar',
#      'hopfavogl',
#      'horst41',
#      'horstelix',
#      'hosenhasser',
#      'hotelneuner',
#      'hschuetz',
#      'hueltera',
#      'huldsfred',
#      'hurdygurdyman',
#      'husky247',
#      'hutzelknecht',
#      'hvb81479',
#      'hwoehrle',
#      'iKaterina',
#      'iMac2015',
#      'iaha',
#      'iangelov',
#      'ianitor',
#      'ibene',
#      'ice-c',
#      'iceboy',
#      'icemanmuc',
#      'ich-liebe-euch',
#      'ichbins2',
#      'iderf',
#      'ikemuc',
#      'ilbeback',
#      'imagic',
#      'imp-cen',
#      'imphil',
#      'intschutschuna',
#      'isarrider',
#      'islandius',
#      'itogo',
#      'ivl1705',
#      'j-c-r-w',
#      'j3d',
#      'j_opa',
#      'jabali',
#      'jacobbraeutigam',
#      'jafu',
#      'jakoala',
#      'jambalaya10',
#      'janelane',
#      'jayd_stevens',
#      'jbau',
#      'jc67',
#      'jekyl',
#      'jelly109',
#      'jengelh',
#      'jensw',
#      'jetri',
#      'jgpacker',
#      'jhl',
#      'jhwist',
#      'jjKlaus',
#      'jjmeissner',
#      'jo91bell',
#      'jo__jo',
#      'joachimlouis',
#      'joe-user',
#      'joedal-osm',
#      'joerg_s',
#      'joergthg',
#      'joglo',
#      'johann568',
#      'johannes4321',
#      'johannesla',
#      'johannesmik',
#      'joi',
#      'jolly63',
#      'jomo999',
#      'josa31',
#      'josuas',
#      'jowu',
#      'jpf',
#      'jpg',
#      u'jr\xf6',
#      'jugenddiakon',
#      'juhaa',
#      'jules16v',
#      'jurtrx',
#      'juststuss',
#      'k127',
#      'k1wi',
#      'k_sch',
#      'kaiotto',
#      'kaiserschmarrn',
#      'kaktus05',
#      'kapege',
#      'karida',
#      'karitotp',
#      "kart'o'graf",
#      'kartenleser',
#      'kartenquizde',
#      'kartler175',
#      'katanga',
#      'kay_D',
#      'kayro76',
#      'kazool',
#      'kbh2002de',
#      'kej45',
#      'keklaus',
#      'kellerma',
#      'kemisch',
#      'kempelen',
#      'kernl',
#      'kilo_echo',
#      'kimmerin',
#      'kirill_aga',
#      'kisaa',
#      'klausis',
#      'kleimaier',
#      'kleinepharaonin',
#      'kleopatra',
#      'klepo',
#      'klml',
#      'knippi',
#      'koelly',
#      'koksnuss',
#      'kommindiegaenge',
#      'konstin',
#      u'kon\xf6',
#      'korpi',
#      'kort-to-osm',
#      'kreh',
#      'kreutzmann',
#      'kreuzschnabel',
#      'kristiankroschel',
#      'krz9000',
#      'krza',
#      'ktmuc',
#      'kuass',
#      'kuddel2000',
#      'kuede',
#      'kujaz2',
#      'kwkmuc',
#      'kyrades',
#      'l3u',
#      'labadotrim',
#      'ladi86',
#      'laifr',
#      'laimer83',
#      'lancaster_od',
#      'landfahrer',
#      'landini',
#      'lanroamer',
#      'lastentaximuenchen',
#      'laufstar1',
#      'lcapka',
#      'lebsanbe',
#      'leftshift',
#      'lefty1963',
#      'legomaster',
#      'lensitivity',
#      'lesi',
#      'lesko987',
#      'levante',
#      'leviathan77',
#      'lgleim',
#      'likesrhubarb',
#      'lingg',
#      'linksunten',
#      'linux-user',
#      'littelteddy',
#      'littlelebowski',
#      'liweisadleader',
#      'lks1',
#      'llit',
#      'lmentrup',
#      'loai_84',
#      'locked',
#      'loewe',
#      'loferer',
#      'loki lier',
#      'loomax',
#      'lubrue',
#      'lucia04',
#      'ludwich',
#      'ludwichx5',
#      'ludwigkamera',
#      'luftpumpe',
#      'luisapig',
#      'luki1051',
#      'lurlrlrl',
#      'luschi',
#      'lutz',
#      'lworch',
#      'lyctkel',
#      'm4c3',
#      'mTb',
#      'mabapla',
#      'mackerski',
#      'macmacs',
#      'macron79',
#      'madmaxm',
#      'maennig',
#      'maggot27',
#      'magicmagnet',
#      'mahgue',
#      'maibua',
#      'mainka',
#      'maipablikkname',
#      'maiwolf',
#      'malenki',
#      'mallok',
#      'malu_muc',
#      'manuel',
#      'map-country',
#      'mapfan',
#      'mapistanbul',
#      'mapper999',
#      'mapperfox',
#      'mapping_kl',
#      'mappinger',
#      'marcel',
#      'marcherzog',
#      'marcoSt',
#      'marek kleciak',
#      'mariuszz',
#      'mark83',
#      'markusd22',
#      'markusmmm',
#      'markusri',
#      'marky-80',
#      'marook',
#      'marsupilcoatl',
#      'martimsilva',
#      'martinJhenne',
#      'martin_minheim',
#      'martinfridrich',
#      'martinhaeusler',
#      'martinheinz',
#      'martunge',
#      'maschuu',
#      'masdfkgjer',
#      'matafumar',
#      'mathsie',
#      'matrizvision',
#      'matzewalter',
#      'maurice2k',
#      'mavrut5',
#      'mawi42',
#      'mawosch',
#      'maxbe',
#      'maxerickson',
#      'maximilian_junker',
#      'mbrunner',
#      'mc64',
#      'mcheckimport',
#      'mctheduck',
#      'mctobler',
#      'mdance31',
#      'mdk',
#      'media2gether',
#      'mehlito',
#      'mehrwertmz',
#      'menkem',
#      'mentzdv_NR',
#      'messi',
#      'metaroll',
#      'mfischell',
#      'mfvl',
#      'mgopub',
#      'mhoram',
#      'micha_k',
#      'michael63',
#      'michael_muenchen',
#      'michael_s',
#      'michaelreinke',
#      'michauch',
#      'miche101',
#      'michigrunf',
#      'micxer',
#      'migar',
#      'mike1703',
#      'mikes',
#      'mikeschneider',
#      'miklas',
#      'miscosm',
#      'mitchmitch',
#      'mitsch',
#      'mixxfixx',
#      'mjack',
#      'mjost',
#      'mkatzbac',
#      'mkbit',
#      'mkbitde',
#      'mkerscher',
#      'mkowa',
#      'mkrafft',
#      'mkrol92',
#      'mkuh',
#      'mlin',
#      'mmd',
#      'mod05',
#      'modreoci',
#      'moemoemoe',
#      'moenk',
#      'mopfattn',
#      'morbus-666',
#      'morklopp',
#      'morlogg',
#      'morray',
#      'morricone',
#      'mouara',
#      'mouch',
#      'mpr',
#      'mrtango',
#      'ms2000',
#      'ms80335',
#      'msaeufferer',
#      'mschaeffler',
#      'msdess',
#      'msm437',
#      'mstangel',
#      'mstock',
#      'mstriewe',
#      'mtbalex',
#      'mtmail',
#      'muc80469',
#      'mucRaubtier',
#      'mucbarney',
#      'mucx',
#      'muenchner',
#      'mueschel',
#      'muetzekoeln',
#      'munich2000',
#      'munichmapper',
#      'munwww',
#      'mw_orion',
#      'mw_zj_ms',
#      'mxmln',
#      'mya9999',
#      'myrcek',
#      'myrkr',
#      'nad-move-max',
#      'nalcakar',
#      'namletrab',
#      'nanashac',
#      'narfg',
#      'naturforscher',
#      'ndrs0815',
#      'negro',
#      'netazon',
#      'netzling',
#      'neuhausr',
#      'neum01',
#      'neumann61',
#      'newman2013',
#      'nickel715',
#      'nilsbe',
#      'nisp',
#      'nixwiehier',
#      'nollsen',
#      'nordlicht81',
#      'normy',
#      'notable',
#      'nouser2014',
#      'novabeat',
#      'nqr',
#      'ntruchsess',
#      'nuepoque',
#      'nur_ich',
#      'nutzervonopenstreetmap',
#      "o'pflanzt is!",
#      'obermenzinger',
#      'obwohl',
#      'occam11',
#      'octo',
#      'oeaffe',
#      'ofendt',
#      'ohhhjojoj',
#      'ohligser',
#      'ojdo',
#      'okilimu',
#      'oleitner',
#      'olipol',
#      'olisi',
#      'oliverlindner',
#      'oliverpool',
#      'onom',
#      'ontong1',
#      'openstreetmapsolln',
#      'orangenbaum',
#      'oreinhardt',
#      'ortylp',
#      'oscarknapp',
#      'osm-sputnik',
#      'osm08',
#      'osm191639',
#      'osm5021985',
#      'osmam',
#      'osmdotorg',
#      'osmkurt',
#      'osmrudi',
#      'osralimto',
#      'ostino',
#      'ottl',
#      'otto1',
#      'ottoderzweite',
#      'ottokar55',
#      'ottomuc',
#      'oudalricus',
#      'pamplo',
#      'paoso',
#      'papamac',
#      'pappou',
#      'parukhin',
#      'pater23',
#      'patwan84',
#      'patzi',
#      'paul2',
#      'paul77',
#      'payx',
#      'pc-coholic',
#      'pdohmen',
#      'pengfield',
#      'perowi',
#      'peter314muc',
#      'peter_s',
#      'peterossege',
#      'pezberg',
#      'pfui_osm_korinthenkacker',
#      'pheahr',
#      'pheckeler',
#      'phg',
#      'phi45',
#      'philipp1704',
#      'phillus',
#      'philopsil',
#      'phis',
#      'phoks',
#      'piaitsch',
#      'pietonnier',
#      'pietzke',
#      'pigmeo1',
#      'pingoo',
#      'pinkpussy',
#      'pirelli789',
#      'piroripo',
#      'pitmap',
#      'pjay1',
#      'planigra',
#      'plexi32',
#      'plmuc',
#      'plush',
#      'pnorman redaction revert',
#      'poliPep',
#      'polymond',
#      'poppei82',
#      'portenkirchner',
#      'poschon',
#      'pradig',
#      'pratikyadav',
#      'proesel',
#      'projecter63',
#      'pseunym_',
#      'pstefan',
#      'pukkoehl',
#      'pyram',
#      'pyrog',
#      'q_un_go',
#      'qaderr',
#      'qnh71',
#      'r_lange',
#      'rab',
#      'rabans',
#      'rabaz',
#      'rabe',
#      'radim_',
#      'rainerr',
#      'raiwal',
#      'ralfwessels',
#      'ralleycorse',
#      'ralphloewe',
#      'ranma',
#      'rarurick',
#      'ratrun',
#      'raupach',
#      'rb706',
#      'reclaM',
#      'redMap',
#      'regedemu',
#      'rejowi',
#      'relaX',
#      'rene-gade',
#      'rene78',
#      'renekorn',
#      'replax',
#      'rhhd',
#      'rhin63',
#      'ric089231281',
#      'richie1st',
#      'rick@ME',
#      'ricot',
#      'riechfield',
#      'rilke1999',
#      'rippeldippel',
#      'ritterrecords',
#      'rjackmuc',
#      'rjacob',
#      'rmuc',
#      'roadyboy',
#      'rob2e',
#      'rob4map',
#      'robbi5',
#      'robekras',
#      'robert balder',
#      'robert rothhardt',
#      'robert7c',
#      'robgeb',
#      'robi74',
#      'robin food',
#      'robnie',
#      'robome',
#      'robs80',
#      'rockhagen',
#      'rofl_kills_lol',
#      'roggy85',
#      'rohrpostix2',
#      'roland_g',
#      'rolandg',
#      'rolf1963',
#      'rolligirl1985',
#      'romanfi',
#      'ronb',
#      'rongaman',
#      'rosch100',
#      'rotico',
#      'rotkelch',
#      'route662',
#      'rrissiek',
#      'rtsx',
#      'rudison',
#      'ruena',
#      'rugbear',
#      'rupps',
#      'rurseekatze',
#      'russek',
#      'rxns',
#      'ryankrueger',
#      'rza31',
#      'rzat80993',
#      's-i-d-e-s-h-o-w---b-o-b',
#      's-o-f',
#      'sMike',
#      's_humbi',
#      'sabas88',
#      'saerdnaer',
#      'safado',
#      'sahar seidl',
#      'sahbeer',
#      'sakudo',
#      'salamifever',
#      'samely',
#      'samle',
#      'santon',
#      'sarupaso',
#      'saschatm',
#      'sat987',
#      'sauls',
#      'saxbav',
#      'sbrinkmann',
#      'schaedl',
#      'schdenis',
#      'schiwi',
#      'schmarn',
#      'schmerzbereiter',
#      'schmu',
#      'schneckchen4711',
#      'schoenis',
#      'schoschi',
#      'schtobia',
#      'schwerebeine',
#      'scirocco22',
#      'seawolff',
#      'sebibinder',
#      'sebp',
#      'seelmann',
#      'seichter',
#      'seiferta',
#      'selkashef',
#      'sendelhorst',
#      'sennewald63',
#      'sequoia',
#      'sgilless',
#      'sgreg',
#      'shazbot',
#      'shentey',
#      'shoarma',
#      'shorshe',
#      'shorty_de',
#      'sidneyshen',
#      'sifnos_gr',
#      'silmaril',
#      'silvavlis',
#      'silviof',
#      'simlox',
#      'simo_n',
#      'simpson71',
#      'sing_de',
#      'sk9',
#      'skurt',
#      'skyb',
#      'slashme',
#      'slhh',
#      'slowtux',
#      'slyon',
#      'smartseven',
#      'smashi',
#      'smial',
#      'smiley87',
#      'smilicevic',
#      'smoky',
#      'snies',
#      'snipermatze',
#      'soemisch',
#      'soeren_gasch',
#      'soet-map',
#      'softeis',
#      'sokke90',
#      'sononum',
#      'species',
#      'speedy',
#      'spezimass',
#      'spickenhahn',
#      'spider_01',
#      'sport_rob',
#      'squiz',
#      'sr855',
#      'sre_i_a_ker',
#      'staehler',
#      'stanton',
#      'stbfloeter',
#      'stefan s',
#      'stefankolling',
#      'stefanwillmeroth',
#      'stefbo',
#      'stefkoebr',
#      'stenzelfilm',
#      'stephan25',
#      'stephankn',
#      'sthama',
#      'sthm',
#      'stilangel',
#      'still-a-worm',
#      'stneu',
#      'stoecker',
#      'stoltzja',
#      'storne',
#      'stratiotis2',
#      'straylght',
#      'streele',
#      'stroth',
#      'studiosusjustus',
#      'stumax',
#      'stumpi80',
#      'sukw',
#      'sulagaloh',
#      'sunfpfiech',
#      'supernova3d',
#      'supersymmetric',
#      'surveyor54',
#      'sushifish',
#      'susi0712',
#      'svbmaier',
#      'svesie',
#      'sw1210',
#      'sw81',
#      'swg62',
#      'swus',
#      't2425b',
#      'tachdbpost',
#      'tamritt',
#      'tanjeff',
#      'tanne',
#      'taoxue',
#      'tattagreis',
#      'tauchkarte',
#      'tausendMedien',
#      'tbleher',
#      'tbp386',
#      'teasu',
#      'tedffo',
#      'teesee',
#      'tefans',
#      'tekap-33',
#      'televator',
#      'textknecht',
#      'the_dusche',
#      'theonlyandy',
#      'theophrastos',
#      'things-change',
#      'thk',
#      'thobie',
#      'thomas-oliver-berlin',
#      'thomas1904',
#      'thomas_kregelin',
#      'thomasdmuc',
#      'thomast11',
#      'thomersch',
#      'thommu',
#      'thorroed',
#      'thowei',
#      'thr4fdb',
#      'thrown-out',
#      'thx1107',
#      'tietze_frank',
#      'tilsti',
#      'timmerma',
#      'timothy_',
#      'timovetter',
#      'timtomm85',
#      'tinooffergeld',
#      'tiototo',
#      'tippobot',
#      'tixuwuoz',
#      'tkarcher',
#      'tklug',
#      'tlou',
#      'tmanyu',
#      'tmcw',
#      'toaster',
#      'tobold',
#      'tom320',
#      'tomie7747',
#      'torstenb',
#      'track_manuel',
#      'trahflow',
#      'traveler-hiker',
#      'travelling_salesman',
#      'tristan_',
#      'trueonestone',
#      'tryagain',
#      'tsturm',
#      'tubaner',
#      'tubeli',
#      'tuerkmentzdv',
#      'turbojoe',
#      'tuxbenz',
#      'tv-arnd',
#      'twaldecker',
#      'twil69',
#      'tydo',
#      'u-strobel',
#      'u14183',
#      'ubahnverleih',
#      'uberdev',
#      'uboot',
#      'uernst',
#      'uft02',
#      'ugerlicher',
#      'uhe',
#      'uhei',
#      'ulfl',
#      'ulfm',
#      'ulikoehler',
#      'ulimativ',
#      'ulmtuelp',
#      'ulrich-dtmd',
#      'ulrichsommer',
#      'um0d',
#      'umeier',
#      'ungusano',
#      'unique2',
#      'unixasket',
#      'unolar',
#      'uptown',
#      'uross',
#      'user38234',
#      'user_1400',
#      'user_34262',
#      'user_5359',
#      'user_7031',
#      'user_7459',
#      'user_7622',
#      'utack',
#      'utiline',
#      'uvi',
#      'uwekosm',
#      'v_mapper',
#      'vademecum',
#      'vale',
#      'valeriohinrichs',
#      'valle129',
#      'van-nerdsen',
#      'vanillabrain',
#      'varlet',
#      'verotours',
#      'ves85',
#      'vid2tepds',
#      'vlamp',
#      'vmeurisse',
#      'vogelfreier',
#      'vokalpartner',
#      'volg',
#      'vollautomat',
#      'vstm',
#      'vstrasser',
#      'vueltaconicarus',
#      'vv01f',
#      'w00lly',
#      'w3box',
#      'wackyusa',
#      'wadelbeisser',
#      'waldviertlerkartograph',
#      'wambacher',
#      'wandsecacher',
#      'wangongtsen',
#      'waschbaer',
#      'waschbaer2013',
#      'waschn',
#      'web_pat',
#      'webbie',
#      'webgeg',
#      'wendorff',
#      'werner2101',
#      'werner_ne',
#      'wggomv',
#      'whb',
#      'wheelmap21',
#      'wheelmap22',
#      'wheelmap23',
#      'wheelmap24',
#      'wheelmap25',
#      'wheelmap26',
#      'wheelmap27',
#      'wheelmap_android',
#      'wheelmap_visitor',
#      'whellmut',
#      'which',
#      'why_not_zoidberg',
#      'wicking',
#      'widedangel',
#      'wiedergaenger',
#      'wieland',
#      'wikimax',
#      'willy+',
#      'winlemski',
#      'wintersportler',
#      'wisieb',
#      'wmann',
#      'wohnung058',
#      'wolf_ics',
#      'wolffisch',
#      'wolfgang_lederer',
#      'wolterh',
#      'wonderlight',
#      'wongang',
#      'woodpeck_fixbot',
#      'woodpeck_repair',
#      'woody-soft',
#      'wor123gap',
#      'wplinge',
#      'wrtlprnft',
#      'wslmude',
#      'wt23',
#      'wuerfelwusel',
#      'wuppiwuppi',
#      'wurz',
#      'wurznsepp',
#      'wuyi',
#      'xcy7e',
#      'xerxes2k',
#      'xlr2009',
#      'xmw',
#      'xnixnix',
#      'xoze',
#      'xporter',
#      'xs400dohc',
#      'xsteadfastx',
#      'xxd19',
#      'xybot',
#      'xylome',
#      'xyz123',
#      'xyzlr',
#      'yakii',
#      'ypid',
#      'ysae',
#      'yzemaze',
#      'zEEs',
#      'zakkum',
#      'zandreas',
#      'zankson',
#      'zap_42',
#      'zapata',
#      'zapthink-muc',
#      'zarl',
#      'zarquon',
#      'zauberberg',
#      'zeckoried',
#      'zed3000',
#      'zepol',
#      'zichwi',
#      'zickzack',
#      'zimba',
#      'zlatan',
#      'zork66',
#      'zugersee',
#      'zuio04',
#      'zulu185',
#      'zumo',
#      'zwutz',
#      'zyklotron',
#      '~0815~',
#      u'\u041a\u043e\u043d\u0441\u0442\u0430\u043d\u0442\u0438\u043d \u041a\u043e\u0446\u0435\u0432'])

# %%
def audit_street_type(street_types, street_name):

    # look for last word in street name
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type in expected:
            return

    # look for ending in street name
    for ends in expectedEnds:
        if re.match(r".*" + ends + "$", street_type):
            return

    # neither last word nor ending matches -> unusual street name
    street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    i = 1
    street_types = defaultdict(set)
    for _, elem in ET.iterparse(osmfile, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    # print tag.attrib["v"]
                    audit_street_type(street_types, tag.attrib['v'])

        if i > 300000:
            sys.stdout.write('*')
            i = 1
        else:
            i += 1

    return street_types

def update_name(name, mapping):

    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            name = street_type_re.sub(mapping[street_type], name)

    return name


if True:
    st_types = audit(OSM)
    pprint.pprint(dict(st_types))
# Out:
# ******************{'Angerlohe': set(['Untere Angerlohe']),
#  u'Autobahn-Rastst\xe4tte-Obermenzing': set([u'Autobahn-Rastst\xe4tte-Obermenzing']),
#  'Bienenkorb': set(['Am Bienenkorb']),
#  'Birkenau': set(['Birkenau']),
#  'Birkicht': set(['Am Birkicht']),
#  'Blankstadl': set(['Am Blankstadl']),
#  u'B\xe4chl': set([u'Am Hartmannshofer B\xe4chl']),
#  'Campeon': set(['Am Campeon']),
#  'Eck': set(['Altheimer Eck']),
#  'Eduard-Stadler-Winkel': set(['Eduard-Stadler-Winkel']),
#  u'Eiche': set([u'Zur Gr\xfcnen Eiche']),
#  u'Eichgeh\xf6lz': set([u'Im Eichgeh\xf6lz']),
#  'Einfang': set(['Am Einfang']),
#  'Einheit': set(['Zur Deutschen Einheit']),
#  u'Einla\xdf': set([u'Am Einla\xdf']),
#  'Emmeram': set(['Sankt Emmeram']),
#  'Eschbichl': set(['Am Eschbichl']),
#  'Eulenhorst': set(['Am Eulenhorst']),
#  'Falkenbeiz': set(['Auf der Falkenbeiz']),
#  u'Feuerb\xe4chl': set([u'Am Feuerb\xe4chl']),
#  'Forst': set(['Am Perlacher Forst']),
#  u'Freiheit': set([u'M\xfcnchner Freiheit']),
#  u'F\xe4hrtwegl': set([u'F\xe4hrtwegl']),
#  'Garten': set(['Englischer Garten']),
#  'Gassenfleckl': set(['Gassenfleckl']),
#  'Gefilde': set(['Im Gefilde']),
#  u'Ger\xe4umt': set([u'Kraillinger Ger\xe4umt']),
#  'Gleisdreieck': set(['Am Gleisdreieck']),
#  'Grund': set(['Im Grund']),
#  u'G\xe4nseb\xfchel': set([u'Am G\xe4nseb\xfchel']),
#  'Haag': set(['Am Haag']),
#  u'Hackerbr\xfccke': set([u'Hackerbr\xfccke']),
#  'Haide': set(['An der Langwieder Haide']),
#  'Hain': set(['Am Hain']),
#  'Hang': set(['Am Hang']),
#  'Harras': set(['Am Harras']),
#  u'Haselnu\xdfstrauch': set([u'Am Haselnu\xdfstrauch']),
#  'Hauptfeuerwache': set(['An der Hauptfeuerwache']),
#  'Heid': set(['Auf der Heid']),
#  'Heide': set(['Alte Heide']),
#  'Heidebruch': set(['Am Heidebruch']),
#  'Heimeranstrasse': set(['Heimeranstrasse']),
#  'Heinrich-Stieglitz-Kehre': set(['Heinrich-Stieglitz-Kehre']),
#  'Herrgottseck': set(['Am Herrgottseck']),
#  'Herterichstrasse': set(['Herterichstrasse']),
#  'Heuluss': set(['In der Heuluss']),
#  u'Hinterbr\xfchl': set([u'Hinterbr\xfchl']),
#  u'Hirteng\xfctl': set([u'Zum Hirteng\xfctl']),
#  'Hochbirken': set(['Hochbirken']),
#  'Hochstand': set(['Am Hochstand']),
#  'Hof': set(['Alter Hof']),
#  'Hofstatt': set(['Hofstatt']),
#  'Hollerbusch': set(['Am Hollerbusch']),
#  'Isar': set(['An der Isar']),
#  'Isarauen': set(['Isarauen']),
#  u'J\xe4gerstern': set([u'Am J\xe4gerstern']),
#  'Kanal': set(['Am Kanal']),
#  u'Kapuzinerh\xf6lzl': set([u'Am Kapuzinerh\xf6lzl']),
#  'Keferloh': set(['Keferloh']),
#  u'Kirchenh\xf6lzl': set([u'Am Kirchenh\xf6lzl']),
#  'Kirschen': set(['In den Kirschen']),
#  u'Klause': set([u'\xdcber der Klause']),
#  'Kleinhesselohe': set(['Kleinhesselohe']),
#  'Klopferspitz': set(['Am Klopferspitz']),
#  'Knie': set(['Am Knie']),
#  'Kreppe': set(['An der Kreppe']),
#  u'Kreuzpl\xe4tzchen': set([u'Kreuzpl\xe4tzchen']),
#  'Kriegersiedlung': set(['Kriegersiedlung']),
#  'Land': set(['Lueg ins Land']),
#  u'Langh\xf6lzl': set([u'Am Langh\xf6lzl']),
#  'Linde': set(['Unter der Linde']),
#  u'L\xe4nge': set([u'Obere L\xe4nge', u'Untere L\xe4nge']),
#  u'L\xfc\xdfl': set([u'Am L\xfc\xdfl']),
#  u'Marienklausenbr\xfccke': set([u'Marienklausenbr\xfccke']),
#  'Menschenrechte': set(['Platz der Menschenrechte']),
#  'Messeturm': set(['Am Messeturm']),
#  u'M\xfchle': set([u'Zur Allacher M\xfchle']),
#  'Neubruch': set(['Am Neubruch']),
#  'Neudeck': set(['Am Neudeck']),
#  'Nymphenbad': set(['Am Nymphenbad']),
#  'Pelkovenstrasse': set(['Pelkovenstrasse']),
#  'Pernerkreppe': set(['Pernerkreppe']),
#  'Platzl': set(['Platzl']),
#  'Praterinsel': set(['Praterinsel']),
#  u'Radenh\xf6lzl': set([u'Am Radenh\xf6lzl']),
#  'Radlsteg': set(['Radlsteg']),
#  'Rindermarkt': set(['Rindermarkt']),
#  'Rosenau': set(['In der Rosenau']),
#  u'Ro\xdfmarkt': set([u'Ro\xdfmarkt']),
#  u'Salzbr\xfccke': set([u'An der Salzbr\xfccke']),
#  'Schanze': set(['An der Schanze']),
#  'Schlag': set(['Lochhamer Schlag']),
#  u'Schlo\xdfmauer': set([u'An der Schlo\xdfmauer']),
#  u'Schlo\xdfrondell': set([u'N\xf6rdliches Schlo\xdfrondell',
#                            u'S\xfcdliches Schlo\xdfrondell']),
#  'Schmiedwegerl': set(['Schmiedwegerl']),
#  'Schrederwiesen': set(['Auf den Schrederwiesen']),
#  u'Sch\xfctzeneck': set([u'Am Sch\xfctzeneck']),
#  'See': set(['Am See']),
#  'Steinheide': set(['Steinheide']),
#  'Stocket': set(['Im Stocket']),
#  'Streicherbreiten': set(['An der Streicherbreiten']),
#  'Tal': set(['Tal']),
#  'Tandlerschlucht': set(['Tandlerschlucht']),
#  u'Theresienh\xf6he': set([u'Theresienh\xf6he']),
#  u'Tor': set([u'Am M\xfcnchner Tor']),
#  'Tuchbleiche': set(['An der Tuchbleiche']),
#  'Viktualienmarkt': set(['Viktualienmarkt']),
#  'Vogelherd': set(['Am Vogelherd']),
#  'Vogelsang': set(['Am Vogelsang']),
#  'Wageck': set(['Am Wageck']),
#  'Waldeslust': set(['Waldeslust']),
#  'Waldesruhe': set(['Waldesruhe']),
#  'Waldheim': set(['Waldheim']),
#  'Waldrand': set(['Am Waldrand']),
#  'Waldspitz': set(['Am Waldspitz']),
#  'Wasen': set(['Auf dem Wasen']),
#  'Wasserturm': set(['Am Aubinger Wasserturm']),
#  'Wiesenhang': set(['Am Wiesenhang']),
#  'Winkel': set(['Am Haderner Winkel']),
#  'Wismat': set(['Im Wismat']),
#  u'W\xe4ldchen': set([u'Am W\xe4ldchen']),
#  u'W\xfcrm': set([u'An der W\xfcrm']),
#  'Zeile': set(['Birtlinger Zeile']),
#  'Ziegelei': set(['Zur Alten Ziegelei'])}

# %%
def audit_city (city_list, name):

    # expected city
    if name in expectedCity:
        return

    # city unexpected
    city_list.add(name)

    return

def is_city(elem):
    return (elem.attrib['k'] == "addr:city")

def audit(osmfile):
    i = 1
    city_list = set()
    for _, elem in ET.iterparse(osmfile, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_city(tag):
                    audit_city(city_list, tag.attrib['v'])

        if i > 300000:
            sys.stdout.write('*')
            i = 1
        else:
            i += 1

    return city_list

# if city name not expected -> replace it from mapping
def update_name(name):

    if name not in expectedCity:
        if name in mappingCity:
            name = mappingCity[name]

    return name

if True:
    city_list = audit(OSM)
    pprint.pprint(city_list)

if True:
    # update city names
    for name in city_list:
        better_name = update_name(name)
        print name, "=>", better_name
# Out:
# ******************set(['Allach',
#      'Aschheim',
#      'Aschheim - Dornach',
#      'Dornach',
#      'Gauting',
#      'Grasbrunn',
#      u'Gr\xe4felfing',
#      u'Gr\xe4felfing bei M\xfcnchen',
#      u'Gr\xfcnwald',
#      'Haar',
#      u'Haar bei M\xfcnchen',
#      'Haar-Gronsdorf',
#      'Haar-Salmdorf',
#      'Hohenbrunn',
#      'Ingolstadt',
#      'Ismaning',
#      'Krailling',
#      'Martinsried',
#      'Munchen',
#      'Munich',
#      u'M\xdc',
#      u'M\xfcchen',
#      u'M\xfcchnen',
#      u'M\xfcnchen - Oberf\xf6hring',
#      u'M\xfcnchen - Trudering',
#      u'M\xfcnchen-Obermenzing',
#      u'M\xfcnchen-Riem',
#      u'M\xfcnchen-Thalkirchen',
#      u'M\xfcnchen-Unterf\xf6hring',
#      u'M\xfcnchen\u200e',
#      u'M\xfcnschen',
#      'Neubiberg',
#      'Neuperlach',
#      'Neuried',
#      'Ottobrunn',
#      'Planegg',
#      'Pullach',
#      'Pullach i. Isartal',
#      'Putzbrunn',
#      'Putzbrunn/Seemannsiedlung',
#      'Putzbrunn/Solalinden',
#      'Putzbrunn/Waldkolonie',
#      'Riezlerweg',
#      'Salmdorf',
#      'Solalinden',
#      'Stockdorf',
#      'Unterbiberg',
#      u'Unterf\xf6hring',
#      'Unterhaching',
#      'Wichernweg'])
# Allach => Allach
# Gauting => Gauting
# Dornach => Dornach
# Wichernweg => Wichernweg
# Gräfelfing => Gräfelfing
# Solalinden => Solalinden
# München - Oberföhring => München - Oberföhring
# Gräfelfing bei München => Gräfelfing
# Grünwald => Grünwald
# Salmdorf => Salmdorf
# München-Obermenzing => München-Obermenzing
# Riezlerweg => Riezlerweg
# München - Trudering => München - Trudering
# Müchnen => München
# München‎ => München
# München-Thalkirchen => München-Thalkirchen
# Grasbrunn => Grasbrunn
# Neubiberg => Neubiberg
# Stockdorf => Stockdorf
# Haar bei München => Haar
# Munich => München
# Ingolstadt => Ingolstadt
# Unterbiberg => Unterbiberg
# Pullach i. Isartal => Pullach i. Isartal
# Neuried => Neuried
# Ismaning => Ismaning
# Ottobrunn => Ottobrunn
# Müchen => München
# Putzbrunn => Putzbrunn
# Unterföhring => Unterföhring
# Haar-Gronsdorf => Haar-Gronsdorf
# Putzbrunn/Solalinden => Putzbrunn/Solalinden
# Hohenbrunn => Hohenbrunn
# Pullach => Pullach
# Putzbrunn/Seemannsiedlung => Putzbrunn/Seemannsiedlung
# Aschheim => Aschheim
# Aschheim - Dornach => Aschheim - Dornach
# Krailling => Krailling
# München-Riem => München-Riem
# Neuperlach => Neuperlach
# Martinsried => Martinsried
# Haar => Haar
# München-Unterföhring => München-Unterföhring
# Münschen => München
# Planegg => Planegg
# Haar-Salmdorf => Haar-Salmdorf
# Munchen => München
# Unterhaching => Unterhaching
# MÜ => München
# Putzbrunn/Waldkolonie => Putzbrunn/Waldkolonie

# %%
# is the current node a city
def is_city(elem):
    return (elem.attrib['k'] == "addr:city")

# if city name not expected -> replace it from mapping
def update_city_name(name):

    if name not in expectedCity:
        if name in mappingCity:
            name = mappingCity[name]

    return name

# shape element for json export
def shape_element(element):
    node = {}
    created = {}
    address = {}
    noderefs = []

    # just the "node" and "way" nodes
    if element.tag == "node" or element.tag == "way" :

        #extract everything the nodes have commonly
        node["id"] = element.attrib["id"]
        node["type"] = element.tag
        if element.get("visible"):
            node["visible"] = element.get("visible")
        if element.tag == "node":
            node["pos"] = [float(element.attrib["lat"]),float(element.attrib["lon"])]

        # get the metadata
        created["version"] = element.get("version")
        created["changeset"] = element.get("changeset")
        created["timestamp"] = element.get("timestamp")
        created["user"] = element.get("user")
        created["uid"] = element.get("uid")
        node["created"] = created

        # process all the other info (tags)
        for i in element.iter():
            if i.tag == "tag":
                k = i.get("k")
                
                # some tags have a "." -> replace it with ":" first 
                k = re.sub("\.", ":", k)
                if problemchars.search(k):
                    # still a character problematic, so skip
                    pass

                elif lower_colon.search(k):
                    if k[0:5] == "addr:":
                        # an address element found -> add to address
                        if is_city(i):
                            # clean city name 
                            address["city"] = update_city_name(i.get("v"))
                        else:
                            # other address fields 
                            address[k[5:]] = i.get("v")
                    else:
                        # lower colon, but no address
                        node[k] = i.get("v")

                else:
                    # other key value
                    node[k] = i.get("v")

            # combine node refs
            if i.tag == "nd":
                noderefs.append(i.get("ref"))

            # an address found
            if address != {}:
                node["address"] = address
                
            # a noderef found
            if noderefs != []:
                node["node_refs"] = noderefs

        return node

    else:
        return None


def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

if True:
    data = process_map(OSM, False)

# %%
import xml.etree.cElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = OSM  # Replace this with your osm file
SAMPLE_FILE = "/Users/wilfriedhoge/Downloads/sample.osm"


def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every 10th top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % 100 == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')
